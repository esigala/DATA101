# %% [markdown]
# # Homework 1: Python Basics
#
# ## Profile
# **Name:** Eidan Sigala <br>
# **Student ID:** M21180677
#
# ## Course Information
# *DATA 101 - Fall 2026*
#
# ## Data Science Topics I'm Excited to Learn About
# 1. Data Visualization
# 2. Machine Learning
# 3. Data Anlysis with Python
#
# ## Fall 2026 Course Schedule
#
# | Course | Credits | Day/Time | Location |
# | --- | --: | --- | --- |
# |CMSC 243| 3 | TR 9:00am - 10:15am | SC 451 |
# |CMSC 140| 4 | TR 11:00am - 12:15pm | SCW 213 |
# |Data 101| 3 | TR 12:30pm - 1:45pm | SC 362 |
# |PSYC 100| 3 | Asynchronous | N/A |
# |BSAD 100| 3 | Asynchronous | N/A |

# %%
#Python Variables and Data Types

#Define Variables
name = "Airpod's Pro 3"
price = 249.99
quantity = 50

#Convert price into an integer and display data type.
price_integar = int(price)
print(type(price_integar))

#Print final statement using variables.
print("We have", quantity, "units of", name, "avaliable at $", price)
# Out:
# <class 'int'>
# We have 50 units of Airpod's Pro 3 avaliable at $ 249.99

# %%
#Basic Arithmetic and Logic

#Calculate total value and display the result
totalValue = (price * quantity)
print("Total value is: $",totalValue)

#Check if total value is greater than $500.
if totalValue > 500:
    print("Total value is greater than $500.")
else:
    print("Toal value is less than $500.")
# Out:
# Total value is: $ 12499.5
# Total value is greater than $500.
